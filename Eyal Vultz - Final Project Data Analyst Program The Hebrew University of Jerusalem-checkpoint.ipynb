# %%
# Importing relevant Python librarires
import pandas as pd
import numpy as np
import matplotlib as bplt

# %%
# Reading the data file
listings = pd.read_csv('listings.csv')

# %%
# Removing duplicated rows and non relevant columns
listings_clean = listings.drop_duplicates().drop(columns = ['listing_url','scrape_id','last_scraped','source','description',
                                          'neighborhood_overview','picture_url','host_url','host_since','host_location',
                                          'host_about','host_response_time','host_response_rate','host_acceptance_rate',
                                          'host_is_superhost','host_thumbnail_url','host_picture_url','host_neighbourhood',
                                          'host_listings_count','host_total_listings_count','host_verifications','host_has_profile_pic',
                                          'neighbourhood_cleansed','neighbourhood_group_cleansed','latitude','longitude',
                                          'bathrooms','bathrooms_text','minimum_nights','maximum_nights','minimum_minimum_nights',
                                          'maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights',
                                          'minimum_nights_avg_ntm','maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
                                          'availability_30','availability_60','availability_90','calendar_last_scraped',
                                          'number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d',
                                          'first_review','last_review','review_scores_rating','review_scores_accuracy',
                                          'review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                                          'review_scores_location','review_scores_value','license','instant_bookable',
                                          'calculated_host_listings_count','calculated_host_listings_count_entire_homes',
                                          'calculated_host_listings_count_private_rooms',
                                          'calculated_host_listings_count_shared_rooms','reviews_per_month'])

# %%
# Filtering Missing values
listings_clean_missing_values = listings_clean.dropna()

# %%
# Fitering out properties which are not located in Washington, United States according to the 'neighbourhood' field 
listings_clean_missing_values_Washington = listings_clean_missing_values[listings_clean_missing_values['neighbourhood'].str.contains("Washington")]

# %%
# Creating a column for the KPI calculation
listings_clean_missing_values_Washington['price'] = listings_clean_missing_values_Washington['price'].replace('\$', '', regex=True).replace('\,', '', regex=True).astype(float)
listings_clean_missing_values_Washington["forecasted_revenue"] = (listings_clean_missing_values_Washington["price"]*(365-listings_clean_missing_values_Washington["availability_365"]))
listings_clean_missing_values_Washington
# Out:
# C:\Users\Shir Vultz\AppData\Local\Temp\ipykernel_10028\3546295621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_clean_missing_values_Washington['price'] = listings_clean_missing_values_Washington['price'].replace('\$', '', regex=True).replace('\,', '', regex=True).astype(float)
# C:\Users\Shir Vultz\AppData\Local\Temp\ipykernel_10028\3546295621.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_clean_missing_values_Washington["forecasted_revenue"] = (listings_clean_missing_values_Washington["price"]*(365-listings_clean_missing_values_Washington["availability_365"]))
#                       id                                               name  \
# 0               13226114  Home in Seattle · ★4.79 · 2 bedrooms · 4 beds ...
# 1               12518952  Guest suite in Seattle · ★5.0 · 2 bedrooms · 6...
# 3               17889172  Rental unit in Seattle · ★5.0 · 1 bedroom · 1 ...
# 5               38328402  Guesthouse in Seattle · ★4.97 · 1 bedroom · 1 ...
# 6     715262634450370999  Condo in Seattle · ★4.94 · 1 bedroom · 1 bed ·...
# ...                  ...                                                ...
# 6622  735966020555767921  Rental unit in Seattle · 2 bedrooms · 2 beds ·...
# 6623            51613147  Rental unit in Seattle · 1 bedroom · 1 bed · 1...
# 6625            13468093  Rental unit in Seattle · ★4.88 · 1 bedroom · 2...
# 6630            33170097      Condo in Seattle · 1 bedroom · 1 bed · 1 bath
# 6633             4400811  Home in Seattle · ★4.85 · 2 bedrooms · 2 beds ...
#
#         host_id      host_name host_identity_verified  \
# 0       1884549  Denise & Sean                      t
# 1      12677600            Joe                      t
# 3      66909032          Randy                      t
# 5       6397518           Sean                      t
# 6      15476414           Kurt                      t
# ...         ...            ...                    ...
# 6622  107434423     Blueground                      t
# 6623  107434423     Blueground                      t
# 6625    3906855         Cheryl                      t
# 6630     627014         Arlene                      t
# 6633    4199445           Liam                      t
#
#                            neighbourhood       property_type        room_type  \
# 0     Seattle, Washington, United States         Entire home  Entire home/apt
# 1     Seattle, Washington, United States  Entire guest suite  Entire home/apt
# 3     Seattle, Washington, United States  Entire rental unit  Entire home/apt
# 5     Seattle, Washington, United States   Entire guesthouse  Entire home/apt
# 6     Seattle, Washington, United States        Entire condo  Entire home/apt
# ...                                  ...                 ...              ...
# 6622  Seattle, Washington, United States  Entire rental unit  Entire home/apt
# 6623  Seattle, Washington, United States  Entire rental unit  Entire home/apt
# 6625  Seattle, Washington, United States  Entire rental unit  Entire home/apt
# 6630  Seattle, Washington, United States        Entire condo  Entire home/apt
# 6633  Seattle, Washington, United States         Entire home  Entire home/apt
#
#       accommodates  bedrooms  beds  \
# 0                5       2.0   4.0
# 1                4       2.0   6.0
# 3                2       1.0   1.0
# 5                2       1.0   1.0
# 6                2       1.0   1.0
# ...            ...       ...   ...
# 6622             4       2.0   2.0
# 6623             2       1.0   1.0
# 6625             1       1.0   2.0
# 6630             1       1.0   1.0
# 6633             5       2.0   2.0
#
#                                               amenities  price  \
# 0     ["Private patio or balcony", "Ceiling fan", "B...  240.0
# 1     ["45\" HDTV with Netflix, HBO Max, Hulu, Amazo...  200.0
# 3     ["Baking sheet", "Carbon monoxide alarm", "Dis...  125.0
# 5     ["Carbon monoxide alarm", "Dishwasher", "50\" ...  148.0
# 6     ["Private patio or balcony", "City skyline vie...  249.0
# ...                                                 ...    ...
# 6622  ["Dryer \u2013\u00a0In unit", "Carbon monoxide...  284.0
# 6623  ["Dryer \u2013\u00a0In unit", "Carbon monoxide...  147.0
# 6625  ["Baking sheet", "Carbon monoxide alarm", "Fir...   78.0
# 6630  ["Hangers", "Wifi", "Pool", "Carbon monoxide a...   40.0
# 6633  ["Private patio or balcony", "Baking sheet", "...  189.0
#
#       availability_365  forecasted_revenue
# 0                    9             85440.0
# 1                  113             50400.0
# 3                  307              7250.0
# 5                  158             30636.0
# 6                    9             88644.0
# ...                ...                 ...
# 6622               266             28116.0
# 6623               306              8673.0
# 6625                 0             28470.0
# 6630                 0             14600.0
# 6633                 2             68607.0
#
# [3738 rows x 15 columns]

# %%
# Statistical data of the Forecasted Revenue of next year Airbnb properties in Washington, United States (The KPI)
listings_clean_missing_values_Washington["forecasted_revenue"].describe()
# Out:
# count    3.738000e+03
# mean     4.325087e+04
# std      6.356976e+04
# min      0.000000e+00
# 25%      1.453950e+04
# 50%      3.454900e+04
# 75%      5.592725e+04
# max      2.190000e+06
# Name: forecasted_revenue, dtype: float64

# %%
# Filtering next year Forecasted Revenue Top 25% (Q1) Airbnb properties in Washington, United States  
listings_clean_missing_values_Washington_Q1 = listings_clean_missing_values_Washington.query('forecasted_revenue >= 5.592725e+04')

# %%
# Next year Forecasted Revenue Top 25% (Q1) Airbnb properties in Washington, United States - Property Type Distribution
listings_clean_missing_values_Washington_Q1_count = listings_clean_missing_values_Washington_Q1['property_type'].value_counts().head(15).plot(kind = 'bar', title = 'Distribution of the Top 25% Next year Forecasted Revenue Properties in Washington, United States (Airbnb data)' , xlabel = 'Property Type', ylabel = 'Next year Forecasted Revenue (USD)')

# %%
# Further Filtering by Neighbourhood The filtered by Property Type the next year Forecasted Revenue Top 25% Airbnb properties in Washington, United States
listings_clean_missing_values_Washington_Q1_Entire_home = listings_clean_missing_values_Washington_Q1[listings_clean_missing_values_Washington_Q1['property_type'].str.contains("Entire home")]

# %%
# Analyzing the above in order to evaluate the Neighborhoods distribution
listings_clean_missing_values_Washington_Q1_Entire_home['neighbourhood'].describe()
# Out:
# count                                    458
# unique                                     1
# top       Seattle, Washington, United States
# freq                                     458
# Name: neighbourhood, dtype: object

# %%
# It seems that the above filtered data relate to properties located only in Seattle, so no need for 'neighbourhood' filtration
# Analyzing the above in order to evaluate the Room Type distribution
listings_clean_missing_values_Washington_Q1_Entire_home['room_type'].describe()
# Out:
# count                 458
# unique                  1
# top       Entire home/apt
# freq                  458
# Name: room_type, dtype: object

# %%
# It seems that the above filtered data relate to only Entire home/apt properties type, so no need for 'room_type' filtration
# Analyzing the above in order to evaluate the Accommodates distribution
listings_clean_missing_values_Washington_Q1_Entire_home.count = listings_clean_missing_values_Washington_Q1_Entire_home['accommodates'].value_counts().head(15).plot(kind = 'bar', title = 'Distribution of the Top 25% Next year Forecasted Revenue Entire Home in Seattle, Washington, United States (Airbnb data)' , xlabel = 'Accommodates', ylabel = 'Next year Forecasted Revenue (USD)')

# %%
# Conclusion: The highest Forecasted Revenue properties in Washington, United States next year, according to Airbnb data are   
# of Entire Home type, with Entire Home / Apartment room type, located in Seattle, and suitable to accommodate 6 people.
